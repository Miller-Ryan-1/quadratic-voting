# %% [markdown]
# # This notebook describes the development of a set of functions seeking to numerically determine the optimal number of quadratic voting credits '*C*' given how many distinct items '*N*' are being voted on.
# - **In sum, given a quadratic ballot with N issues, how many voting credits should be given?**
#
# ## 1.  This was done to address one of the strongest criticisms of Quadratic Voting (QV), wasted voting power (vote credits that cannot be used without changing the voting intention of the voter).  This is particularly true of small N ballots.
#
# #### *Note: Another way of doing QV is through continuous, or "infinitely divisible" votes.  Thus, a voter can use any N real numbers that when squared and added together equal C.  While this solves the wasted credit issue, there are still game theory implications to different levels of C.  This is a future path of investigation.*
#
# ## 2.  As mentioned in the note above, there are optimal strategies from both a game theory and computational front.
#
# ## 3.  Limitations:  This notebook is limited to discrete, positive integer votes.  It does not take into account negative votes for a ballot item like many QV frameworks do.  Having negative votes will likely alter the method of selecting strategies and is another path of investigation.  Also, perfectly rational voters are asumed - thus, while the model only uses rational strategies in its mechanics, in reality the voters will have the full set of possibilities to choose from, including ones where they have a better strategy than what their voting is, or making suboptimal tradeoffs.  This should be irrelevant, as strategy sets should be judged on rational voting.

# %% [markdown]
# ----

# %% [markdown]
# #### Libraries Used

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA
import math
from itertools import combinations_with_replacement, groupby
from math import floor
import re

# %% [markdown]
# ----

# %% [markdown]
# ## Key Terms and Concepts Explored Below
# 1. QUADRATIC VOTING (QV): Voting method where voters are given a number of voting credits 'C' and allowed to distribute them across a series of N-items.  The credits convert to tallied votes at a rate of $\sqrt(C)$ per voting item.
#
# 2. DECISION SPACE: The collection of N-items being quadratically voted on, where N is a positive integer.  Basically a ballot.
#
# 3. VOTING ITEM: One of N-items (voting choices) that a voter can spend voting power on.
#
# 4. VOTER: An individual who choses a voting strategy by assinging voting power, quadratically, across voting items within an N-sized decision space.
#
# 5. VOTE: How much voting power is ultiamtely assigned to a Voting Item given the voter's strategy. $V = \sqrt(C)$
#
# 6. VOTE CREDIT: 'C' units of voting power which convert into votes quadratically.  The goal of this notebook is to find optimal values of C given N.
#
# 7. STRATEGY: The set of numbers which represent how a voter voted using their voting power.  For example, when N = 4 & C = 50, one voting strategy that wastes no credits would be: [7,1,0,0].  Strategies go from highest vote count on the left to lowest on the right as each strategy represents all equivalent voting strategies (i.e. [4,2,1,0,0] == [2,4,0,0,1]
#
# 8. MAX VOTE: 'Vmax' = The maximum possible vote on a single voting item for a given C.  Always lower than total votes from a given strategy, unless C is a perfect square and all voting power is used on a single voting item; in that case they are equal.
#
# 9. NULL STRATEGY: A voting strategy where all votes are equivalent, ie. [2,2,2], [4,4,4,4,4,4], etc..  These are all equivalnet to [0,..,0], aka not voting.
#
# 10. STRATEGY SET: The collection of strategies available for a given set of parameters (N and m or C).  Range from "Complete" (all non-null strategies, with Equivalent Strategies consolidated to one) to "Reduced Form".
#
# 10. REDUCED FROM (OF STRATEGY SET): The set of strategies that use the minimal number of votes to express a group of voters relative preferences.
#
# 11. EQUIVALENT STRATEGY: Equivalent strategies are all permutations of the same numbers within the voting space.  As such they combined into one for the analysis.  For example strategy [2,2,1] == [2,1,2] == [1,2,2].

# %% [markdown]
# ## Assumptions
# 1. All null strategies are equivalent.
# 2. All equivalent strategies are equivalent.
# 3. N = 1 decouples into N = 2
# 4. For N = 2, there is only one strategy, [1,0].  Therefore C(2) = 1.
# 5. Voters are rational.  They will only waste voting credits if it fits their preferred strategy, and strategies suffer a penalty for wasting votes (waste factor).
# 6. Voters will always seek to maximize their largest vote element rather than waste votes.
# 7. Voters most concerned about the fairness of their vote, not the absolute.

# %% [markdown]
# ## Process Steps
# 1. Create the complete strategy set given N and a number of voice credits C (include strategies).
# 2. Reduce the strategy set to rational strategies (reduced form).
# 3. Determine key metrics for strategy sets of different values of C.
# 4. Compare all strategy sets for a given N to determine which value of C is optimal (allows for comprehensive voting actions and equitable strategies).

# %% [markdown]
# ----

# %% [markdown]
# ## STEP 1: Create the sets of unique voting strategies for a given N-sized decision space bounded by different numbers of voice credits, C.

# %% [markdown]
# The method used first assigns a value 'm' to represent the highest number of votes a voter can apply to a single voting item.
#
# For example, the full solution set of strategies for [N = 3, m = 2] would be:
# [2,2,2], [2,2,1], [2,1,1], [2,1,0], [2,0,0], [1,1,1], [1,1,0], [1,0,0], [0,0,0]
#
#     Note: [2,2,1] == [2,1,2] == [1,2,2], where [2,2,1] is the 'representative form'
#
# Also, all null strategies are dropped, thus leaving the "null-free" solution set as:
# [2,2,1], [2,1,1], [2,1,0], [2,0,0], [1,1,0], [1,0,0]

# %% [markdown]
# ### 1a. Build all strategies for a given N up to the strategy set [m,m,...,m-1] .
#     Note: The strategy set [m,m,...,m] results in the null strategy, so it is not included as all null strategies should be removed.  Also, equivalent strategies should be combined into one.

# %%
def strategies_for_n_given_m(m, N):
    '''
    Returns possible voting strategies, along with the total votes given by the strategies and the strategy's
    total cost in credits.
    
    Parameters:
        int m = Top limit/max number of votes for a voting item
        int N = Number of Issues
        
    Returns:
        obj output = List of dicts showing complete strategy set for N given m, with total votes and credits calculated.         
    '''
    # Create an iterable for all values from 0 to m:
    numbers = list(range(m + 1))
    
    # Generate all unique combinations of length N from the numbers 0 to m
    combs = list(combinations_with_replacement(numbers, N))
    
    # Remove equivalent strategies (e.g. [2,1] == [1,2]).  !-set() looks at both numbers:
    combs = list(set(c for c in combs))
    
    # Sort each list in descending order - descending because the convention is to list them high to low
    combs = sorted(combs, key=lambda x: x[::-1], reverse = True)
    
    # Create return object - a list of dicts for easy df creation
    output = []
    
    # Get the vote credit total needed for each strategy
    for i in combs:
        # FIRST FILTER: Remove all strategies where the elements are equal (equilvalent to Null Vote)
        if i == i[0:1] * N:
            #print(f'Voting strategy {i} == Null Vote.  Removed.')
            continue
            
        # If not a null strategy, build an entry for output
        else:    
            i = sorted(i, reverse = True)
            
            # Create an object to hold the strategy and its total votes and vote_credits needed
            output_dict = {}
            output_dict['strategy'] = i
            
            output_dict['vote_sum'] = sum(i)
            output_dict['vote_credits'] = sum([p**2 for p in i])
            
            output.append(output_dict) 
    
    return output

# %%
complete_strats = strategies_for_n_given_m(4, 4)
complete_strats, len(complete_strats)
# Out:
# ([{'strategy': [4, 4, 4, 3], 'vote_sum': 15, 'vote_credits': 57},
#   {'strategy': [4, 4, 4, 2], 'vote_sum': 14, 'vote_credits': 52},
#   {'strategy': [4, 4, 4, 1], 'vote_sum': 13, 'vote_credits': 49},
#   {'strategy': [4, 4, 4, 0], 'vote_sum': 12, 'vote_credits': 48},
#   {'strategy': [4, 4, 3, 3], 'vote_sum': 14, 'vote_credits': 50},
#   {'strategy': [4, 4, 3, 2], 'vote_sum': 13, 'vote_credits': 45},
#   {'strategy': [4, 4, 3, 1], 'vote_sum': 12, 'vote_credits': 42},
#   {'strategy': [4, 4, 3, 0], 'vote_sum': 11, 'vote_credits': 41},
#   {'strategy': [4, 4, 2, 2], 'vote_sum': 12, 'vote_credits': 40},
#   {'strategy': [4, 4, 2, 1], 'vote_sum': 11, 'vote_credits': 37},
#   {'strategy': [4, 4, 2, 0], 'vote_sum': 10, 'vote_credits': 36},
#   {'strategy': [4, 4, 1, 1], 'vote_sum': 10, 'vote_credits': 34},
#   {'strategy': [4, 4, 1, 0], 'vote_sum': 9, 'vote_credits': 33},
#   {'strategy': [4, 4, 0, 0], 'vote_sum': 8, 'vote_credits': 32},
#   {'strategy': [4, 3, 3, 3], 'vote_sum': 13, 'vote_credits': 43},
#   {'strategy': [4, 3, 3, 2], 'vote_sum': 12, 'vote_credits': 38},
#   {'strategy': [4, 3, 3, 1], 'vote_sum': 11, 'vote_credits': 35},
#   {'strategy': [4, 3, 3, 0], 'vote_sum': 10, 'vote_credits': 34},
#   {'strategy': [4, 3, 2, 2], 'vote_sum': 11, 'vote_credits': 33},
#   {'strategy': [4, 3, 2, 1], 'vote_sum': 10, 'vote_credits': 30},
#   {'strategy': [4, 3, 2, 0], 'vote_sum': 9, 'vote_credits': 29},
#   {'strategy': [4, 3, 1, 1], 'vote_sum': 9, 'vote_credits': 27},
#   {'strategy': [4, 3, 1, 0], 'vote_sum': 8, 'vote_credits': 26},
#   {'strategy': [4, 3, 0, 0], 'vote_sum': 7, 'vote_credits': 25},
#   {'strategy': [4, 2, 2, 2], 'vote_sum': 10, 'vote_credits': 28},
#   {'strategy': [4, 2, 2, 1], 'vote_sum': 9, 'vote_credits': 25},
#   {'strategy': [4, 2, 2, 0], 'vote_sum': 8, 'vote_credits': 24},
#   {'strategy': [4, 2, 1, 1], 'vote_sum': 8, 'vote_credits': 22},
#   {'strategy': [4, 2, 1, 0], 'vote_sum': 7, 'vote_credits': 21},
#   {'strategy': [4, 2, 0, 0], 'vote_sum': 6, 'vote_credits': 20},
#   {'strategy': [4, 1, 1, 1], 'vote_sum': 7, 'vote_credits': 19},
#   {'strategy': [4, 1, 1, 0], 'vote_sum': 6, 'vote_credits': 18},
#   {'strategy': [4, 1, 0, 0], 'vote_sum': 5, 'vote_credits': 17},
#   {'strategy': [4, 0, 0, 0], 'vote_sum': 4, 'vote_credits': 16},
#   {'strategy': [3, 3, 3, 2], 'vote_sum': 11, 'vote_credits': 31},
#   {'strategy': [3, 3, 3, 1], 'vote_sum': 10, 'vote_credits': 28},
#   {'strategy': [3, 3, 3, 0], 'vote_sum': 9, 'vote_credits': 27},
#   {'strategy': [3, 3, 2, 2], 'vote_sum': 10, 'vote_credits': 26},
#   {'strategy': [3, 3, 2, 1], 'vote_sum': 9, 'vote_credits': 23},
#   {'strategy': [3, 3, 2, 0], 'vote_sum': 8, 'vote_credits': 22},
#   {'strategy': [3, 3, 1, 1], 'vote_sum': 8, 'vote_credits': 20},
#   {'strategy': [3, 3, 1, 0], 'vote_sum': 7, 'vote_credits': 19},
#   {'strategy': [3, 3, 0, 0], 'vote_sum': 6, 'vote_credits': 18},
#   {'strategy': [3, 2, 2, 2], 'vote_sum': 9, 'vote_credits': 21},
#   {'strategy': [3, 2, 2, 1], 'vote_sum': 8, 'vote_credits': 18},
#   {'strategy': [3, 2, 2, 0], 'vote_sum': 7, 'vote_credits': 17},
#   {'strategy': [3, 2, 1, 1], 'vote_sum': 7, 'vote_credits': 15},
#   {'strategy': [3, 2, 1, 0], 'vote_sum': 6, 'vote_credits': 14},
#   {'strategy': [3, 2, 0, 0], 'vote_sum': 5, 'vote_credits': 13},
#   {'strategy': [3, 1, 1, 1], 'vote_sum': 6, 'vote_credits': 12},
#   {'strategy': [3, 1, 1, 0], 'vote_sum': 5, 'vote_credits': 11},
#   {'strategy': [3, 1, 0, 0], 'vote_sum': 4, 'vote_credits': 10},
#   {'strategy': [3, 0, 0, 0], 'vote_sum': 3, 'vote_credits': 9},
#   {'strategy': [2, 2, 2, 1], 'vote_sum': 7, 'vote_credits': 13},
#   {'strategy': [2, 2, 2, 0], 'vote_sum': 6, 'vote_credits': 12},
#   {'strategy': [2, 2, 1, 1], 'vote_sum': 6, 'vote_credits': 10},
#   {'strategy': [2, 2, 1, 0], 'vote_sum': 5, 'vote_credits': 9},
#   {'strategy': [2, 2, 0, 0], 'vote_sum': 4, 'vote_credits': 8},
#   {'strategy': [2, 1, 1, 1], 'vote_sum': 5, 'vote_credits': 7},
#   {'strategy': [2, 1, 1, 0], 'vote_sum': 4, 'vote_credits': 6},
#   {'strategy': [2, 1, 0, 0], 'vote_sum': 3, 'vote_credits': 5},
#   {'strategy': [2, 0, 0, 0], 'vote_sum': 2, 'vote_credits': 4},
#   {'strategy': [1, 1, 1, 0], 'vote_sum': 3, 'vote_credits': 3},
#   {'strategy': [1, 1, 0, 0], 'vote_sum': 2, 'vote_credits': 2},
#   {'strategy': [1, 0, 0, 0], 'vote_sum': 1, 'vote_credits': 1}],
#  65)

# %% [markdown]
# > For N = 4 and m = 4, there are 65 null-less strategies representing a range of voting credits needed as well as some additional information.

# %% [markdown]
# #### In general, the formula for determining the number of non-null strategies given m (where m = positive integer) and n (n>1) is:
#
#     s = ((m+1) * (m+2) * ... * (m+n)) / n!
#
# #### And given m (where m is both a positive and negative integer):
#
#     s = ((2m + 1) * (2m + 2) * ... * (2m+n)) / n!

# %% [markdown]
# ### 1b. Build the strategy set by creating m from vote credits and filtering out all stategies that do not work with the given vote credit amount.

# %%
def build_strategy_set(N, vote_credits):
    '''
    Use vote credits to filter out stragies from a complete N,m strategy set.
        
    Parameters:
        int N = Number of Issues
        int vote_credits = C = Maximum amount of vote credits to get N-length strategies for
        
    Returns:
        obj s_set = Dataframe with all possible strategies along with their vote totals and credit requirements up to C. 
    '''
    # First identify the value of m, which is the highest possible value for an individual Voting Item's total.
    m = floor(vote_credits**.5)
   
    # Now create and filter out all strategies with C greater than given vote_credits
    s_set = pd.DataFrame(strategies_for_n_given_m(m,N))
    s_set = s_set[s_set['vote_credits'] <= vote_credits]
    s_set = s_set.reset_index(drop = True)
    
    return s_set

# %%
build_strategy_set(4, 50)
# Out:
#          strategy  vote_sum  vote_credits
# 0    [7, 1, 0, 0]         8            50
# 1    [7, 0, 0, 0]         7            49
# 2    [6, 3, 2, 1]        12            50
# 3    [6, 3, 2, 0]        11            49
# 4    [6, 3, 1, 1]        11            47
# ..            ...       ...           ...
# 102  [2, 1, 0, 0]         3             5
# 103  [2, 0, 0, 0]         2             4
# 104  [1, 1, 1, 0]         3             3
# 105  [1, 1, 0, 0]         2             2
# 106  [1, 0, 0, 0]         1             1
#
# [107 rows x 3 columns]

# %% [markdown]
# ## STEP 2: Reduce the strategy set to rational strategies (reduced form).

# %% [markdown]
# There are two reductions that need to happen to reduce to rational strategies (that is strategies that aren't equivalent):
# 1. 'Arithmatic': Where each strategy element is reduced by one until at least one element is zero. *For +/-m, reduction means get 1 integer closer to zero.  The non-reduced strategy is eliminated.
#     Ex. [4,3,2,2] ~ [3,2,1,1] ~ [2,1,0,0]
#
# 2. 'Multiplicative': Where each strategy element is divided by a number such that the result for each is an integer.
#     Ex. [8,6,6,6,4] ~ [4,3,3,3,2]; Note: 0 divided by any number is an integer.  The reduced strategy is eliminated.
#
# Both reduce the strategy set by removing arithmatically equivalent strategies (different than equivalent strategies above).

# %% [markdown]
# ### 2a. Create a subfunction to reduce to lowest form, that means the smallest equivalent voting pattern (made by subtracting one from each vote until there is a zero column).

# %%
def arithmatic_reduction(strategy_list):
    '''
    Reduce strategy set by going through strategies and seeing if each can be reduced, and if so appending
    a return list with that rather than the original strategy.
    
    Parameters:
        obj df = Df with strategies
        
    Returns:
        obj new_strat_list = List of strategies after arithatic reduction
    '''
    # Create the holder for the output
    new_strat_list = []
    # Create the holder for strategies to remove
    remove_strats = []
    
    #strategy_list = df.strategy

    # Test each strategy to find cases where the elements are 1 vote off, and can therefore be removed.
    for strategy in strategy_list:
        # Break swith breaks out of loop
        mod_strategy = []
        for element in strategy:
            new_element = element - 1
            mod_strategy.append(new_element)
        
        remove_strats.append(mod_strategy)
        
    for strategy in strategy_list:
        if strategy in remove_strats:
            continue
        else:
            new_strat_list.append(strategy)
        
    return new_strat_list

# %%
arithmatic_reduction(build_strategy_set(4, 50).strategy)
# Out:
# [[7, 1, 0, 0],
#  [7, 0, 0, 0],
#  [6, 3, 2, 1],
#  [6, 3, 2, 0],
#  [6, 3, 1, 1],
#  [6, 3, 1, 0],
#  [6, 3, 0, 0],
#  [6, 2, 2, 2],
#  [6, 2, 2, 1],
#  [6, 2, 2, 0],
#  [6, 2, 1, 1],
#  [6, 2, 1, 0],
#  [6, 2, 0, 0],
#  [6, 1, 1, 1],
#  [6, 1, 1, 0],
#  [6, 1, 0, 0],
#  [6, 0, 0, 0],
#  [5, 5, 0, 0],
#  [5, 4, 3, 0],
#  [5, 4, 2, 2],
#  [5, 4, 2, 1],
#  [5, 4, 2, 0],
#  [5, 4, 1, 1],
#  [5, 4, 1, 0],
#  [5, 4, 0, 0],
#  [5, 3, 3, 2],
#  [5, 3, 3, 1],
#  [5, 3, 3, 0],
#  [5, 3, 2, 2],
#  [5, 3, 2, 1],
#  [5, 3, 2, 0],
#  [5, 3, 1, 1],
#  [5, 3, 1, 0],
#  [5, 3, 0, 0],
#  [5, 2, 2, 2],
#  [5, 2, 2, 1],
#  [5, 2, 2, 0],
#  [5, 2, 1, 1],
#  [4, 4, 4, 1],
#  [4, 4, 4, 0],
#  [4, 4, 3, 3],
#  [4, 4, 3, 2],
#  [4, 4, 3, 1],
#  [4, 4, 3, 0],
#  [4, 4, 2, 2],
#  [4, 4, 2, 1],
#  [4, 4, 2, 0],
#  [4, 4, 1, 1],
#  [4, 4, 1, 0],
#  [4, 4, 0, 0],
#  [4, 3, 3, 3],
#  [4, 3, 3, 2],
#  [4, 3, 3, 1],
#  [4, 3, 3, 0],
#  [4, 3, 2, 2],
#  [4, 3, 2, 1],
#  [4, 3, 2, 0],
#  [4, 2, 2, 2],
#  [3, 3, 3, 2],
#  [3, 3, 3, 1]]

# %% [markdown]
# ### 2c. Second reduction, to be applied in larger function.

# %%
def remove_similar(strategy_list):
    '''
    This is the multiplicative reduction.  It analyzes each as a vector to see if they have the same unit vector, 
    meaning they are scalar multiples of one another.  It removes the duplicate vector with the lower magnitude.
    
    Parameters:
        obj strategy_list = List of strategies
        
    Returns:
        obj unique_vectors = List of multiplicatively reduced strategies
    '''
    unique_vectors = []

    for v in strategy_list:
        unit_vector = v / LA.norm(v)
        is_unique = True
        for uv in unique_vectors:
            uv_unit_vector = uv / LA.norm(uv)
            if all(unit_vector == uv_unit_vector):
                if LA.norm(uv) < LA.norm(v):
                    unique_vectors.remove(uv)
                    unique_vectors.append(v) 
                    unique_vectors.remove(v)

                is_unique = False
                break
        if is_unique:
            unique_vectors.append(v)
            
    return unique_vectors

# %%
remove_similar(build_strategy_set(4, 50).strategy)
# Out:
# [[7, 1, 0, 0],
#  [7, 0, 0, 0],
#  [6, 3, 2, 1],
#  [6, 3, 2, 0],
#  [6, 3, 1, 1],
#  [6, 3, 1, 0],
#  [6, 3, 0, 0],
#  [6, 2, 2, 2],
#  [6, 2, 2, 1],
#  [6, 2, 2, 0],
#  [6, 2, 1, 1],
#  [6, 2, 1, 0],
#  [6, 2, 0, 0],
#  [6, 1, 1, 1],
#  [6, 1, 1, 0],
#  [6, 1, 0, 0],
#  [5, 5, 0, 0],
#  [5, 4, 3, 0],
#  [5, 4, 2, 2],
#  [5, 4, 2, 1],
#  [5, 4, 2, 0],
#  [5, 4, 1, 1],
#  [5, 4, 1, 0],
#  [5, 4, 0, 0],
#  [5, 3, 3, 2],
#  [5, 3, 3, 1],
#  [5, 3, 3, 0],
#  [5, 3, 2, 2],
#  [5, 3, 2, 1],
#  [5, 3, 2, 0],
#  [5, 3, 1, 1],
#  [5, 3, 1, 0],
#  [5, 3, 0, 0],
#  [5, 2, 2, 2],
#  [5, 2, 2, 1],
#  [5, 2, 2, 0],
#  [5, 2, 1, 1],
#  [5, 2, 1, 0],
#  [5, 2, 0, 0],
#  [5, 1, 1, 1],
#  [5, 1, 1, 0],
#  [5, 1, 0, 0],
#  [4, 4, 4, 1],
#  [4, 4, 4, 0],
#  [4, 4, 3, 3],
#  [4, 4, 3, 2],
#  [4, 4, 3, 1],
#  [4, 4, 3, 0],
#  [4, 4, 2, 2],
#  [4, 4, 2, 1],
#  [4, 4, 2, 0],
#  [4, 4, 1, 1],
#  [4, 4, 1, 0],
#  [4, 3, 3, 3],
#  [4, 3, 3, 2],
#  [4, 3, 3, 1],
#  [4, 3, 3, 0],
#  [4, 3, 2, 2],
#  [4, 3, 2, 1],
#  [4, 3, 2, 0],
#  [4, 3, 1, 1],
#  [4, 3, 1, 0],
#  [4, 3, 0, 0],
#  [4, 2, 2, 2],
#  [4, 2, 2, 1],
#  [4, 2, 2, 0],
#  [4, 2, 1, 1],
#  [4, 2, 1, 0],
#  [4, 1, 1, 1],
#  [4, 1, 1, 0],
#  [4, 1, 0, 0],
#  [3, 3, 3, 2],
#  [3, 3, 3, 1],
#  [3, 3, 3, 0],
#  [3, 3, 2, 2],
#  [3, 3, 2, 1],
#  [3, 3, 2, 0],
#  [3, 3, 1, 1],
#  [3, 3, 1, 0],
#  [3, 3, 0, 0],
#  [3, 2, 2, 2],
#  [3, 2, 2, 1],
#  [3, 2, 2, 0],
#  [3, 2, 1, 1],
#  [3, 2, 1, 0],
#  [3, 2, 0, 0],
#  [2, 2, 2, 1]]

# %% [markdown]
# ### 2d. Create function that determines inefficent statategies and then removes them, finding the 'cutoff' for the inefficiency.  For example, if you have [4,1,0] and you can vote [5,1,0] and waste less credits, you do the latter.  The amount of wasted credits in [4,1,0] becomes the maximum + 1 wasted credit limit.

# %%
def get_cutoff(strategies):
    '''
    Finds the highest vote total strategy which is inefficient, meaning there is a better voting strategy.
    For example, if a voter has both [5,1,0] and [4,1,0] available to them, the would always rationally go with
    the [5,1,0], as one of the principles to voting is its less about ratios since all are voting items are 
    independant except for the decision itself.  Thus, the case for this is where all but the max vote total
    are the same between two strategies, and the max vote of one is higher.
    
    Parameters:
        obj strategies = List of strategies
        
    Returns:
        str = List in string form of cutoff strategy
    '''
    strategies.reverse()
    for item_a in strategies:
        for item_b in strategies:
            if [a - b for a, b in zip(item_a, item_b)] == [1] + [0] * (len(item_a)-1):
                if item_b[0] != item_b[1]:
                    return str(item_b)

# %%
get_cutoff(list(build_strategy_set(4, 50).strategy))
# Out:
# '[1, 0, 0, 0]'

# %% [markdown]
# ### 2e. Lastly create the difference analysis, which creates the metrics for the strategy sets to be compared to one another

# %%
def vote_difference_analysis(strategy):
    '''
    Outputs some comparison metrics about the individual voting items within a strategy.
    
    Parameters:
        obj strategy = List of integers
        
    Returns:
        int max_diff = Minimum difference of votes across voting elements
        int min_diff = Maximum difference of votes across voting elements
        int max_min_diff = Difference between max and min vote differences
        float avg_diff = Average of differences of votes across voting elements
    '''
    # Create a list to hold differences between votes for strategy
    res = []
    
    for i in range(len(strategy)):
        for j in range(len(strategy)):
            if i != j:
                res.append(abs(strategy[i] - strategy[j]))
    
    # Get vote differences
    max_diff = max(res)
    min_diff = min(res)
    max_min_diff = max_diff - min_diff
    avg_diff = round(sum(res)/len(res), 4)
    
    return max_diff, min_diff, max_min_diff, avg_diff

# %% [markdown]
# ## STEP 3: Determine key metrics for strategy sets of different values of C, given N

# %%
'Determine key metrics for strategy sets of different values of C, given N'.upper()
# Out:
# 'DETERMINE KEY METRICS FOR STRATEGY SETS OF DIFFERENT VALUES OF C, GIVEN N'

# %%
def strategies_for_n(N, max_credits):
    '''
    Given a number of max credits, determine all viable strategy options for N.
    Basically: set max_credits, run the function, then pick lowest C that optimizes the voting pattern.
    
    Parameters:
        int N = Number of Issues
        int max_credits = Cmax = Maximum amount of vote credits to get N-length strategies for
        
    Returns:
        obj credit_outcomes = Dataframe with details on strategy sets for each C in N up to Cmax
    '''
    strategies = build_strategy_set(N, max_credits).sort_values(by = 'vote_credits')
    
    credit_outcomes = []
    
    for i in range(1, max_credits + 1):
        
        print('Voice Credits:',i)
        
        # Vote max for the given i
        vmax = floor(i**.5)
        
        # Create list object to hold dicts ceated from strategy details
        result = []        
        
        # Extract the strategies that work with this number of votes
        strats_in_i = strategies[strategies['vote_credits'] <= i]
        strat_list = list(strats_in_i.strategy)
    
        strat_list = arithmatic_reduction(strat_list)
        
        # You can now remove the similar strategies having removed any ones higher that would skew this output
        strat_list = remove_similar(strat_list)

        strats_in_i = strats_in_i[strats_in_i.strategy.isin(strat_list)]
        
        # Create the metrics for each strategy
        for row in strats_in_i.strategy:
            # Basic info
            output = {}
            output['strategy'] = row
            row_votes = sum(row)
            row_vc = sum([x**2 for x in row])
            output['votes per credit'] = row_votes/row_vc

            output['wasted_credits'] = i - row_vc
            
            # Difference metrics
            max_diff, min_diff, max_min_diff, avg_diff = vote_difference_analysis(row)
                
            output['min_vote_diff'] = min_diff
            output['max_vote_diff'] = max_diff
            output['max_min_diff'] = max_min_diff
            output['avg_diff'] = avg_diff
            
            # Scoring metrics
            output['votes_over_vmax'] = row_votes - vmax
            output['credits_over_vmax'] = row_vc - vmax**2
            
            # Create a weight factor for each strategy 
            # This will weight each strategy's effect on the strategy set of a given C
            # !- vary wf below 
            wf = .5
            output['WF1'] = wf**(output['wasted_credits'])
            result.append(output)
        
        result = pd.DataFrame(result)
        
        # Make a list of strategies available for N
        n_strategies = list(result.strategy)

        # Identify a 'cutoff' strategy = last filter
        cutoff_strategy = get_cutoff(n_strategies)
        print('cutoff_strategy',cutoff_strategy)

        # Need to change strategy back into a string
        result = result.astype({'strategy':str})

        # Find cutoff strategy and how many credits it wastes
        wasted_credits_cutoff = result[result['strategy'] == cutoff_strategy]['wasted_credits'].values
        print('wasted_credits_cutoff',wasted_credits_cutoff)

        # Remove all strategies which waste more credits than the cutoff (including the cutoff)
        if len(wasted_credits_cutoff) > 0:
            result = result[result['wasted_credits'] < wasted_credits_cutoff[0]]
            
        # Create additional score columns using weight factor
        result['weighted_score'] = (result['votes_over_vmax'] + result['credits_over_vmax']) * result['WF1']
        
        ## ## ## WEIGHTED DIFFERENCES
        result['min_vote_diff'] = result['min_vote_diff'] * result['WF1']
        result['max_vote_diff'] = result['max_vote_diff'] * result['WF1']
        result['max_min_diff'] = result['max_min_diff'] * result['WF1']
        result['avg_diff'] = result['avg_diff'] * result['WF1']
        ## ## ##
         
        # Create Strategy Set metrics for a given C
        sc = len(result) # Count of strategies
        v_c = result['votes per credit'].mean() 
        wc_s = result['wasted_credits'].sum() # Sum of wasted votes
        wc_m = result['wasted_credits'].mean() # Average of wasted credits for all strategies
        min_vd_m = result['min_vote_diff'].mean()
        max_vd_m = result['max_vote_diff'].mean()
        d_vd_m = result['max_min_diff'].mean()
        avg_diff_m = result['avg_diff'].mean()
        score_s = result['weighted_score'].sum()
        score_m = result['weighted_score'].mean()
        wf_s = result['WF1'].sum()
        wf_m = result['WF1'].mean()
        
        credit_outcomes.append({'Credits':i,
                                'Strategies':sc,
                                'Votes per Credit':v_c,
                                'Total Wasted Credits':wc_s,
                                'Avg. Wasted Credits per Strategy':wc_m,
                                'Avg. Min Vote Diff':min_vd_m,
                                'Avg. Max Vote Diff':max_vd_m,
                                'Avg. MinMax Vote Diff':d_vd_m,
                                'Avg. Diff':avg_diff_m,
                                'Avg. Score':score_m,
                                'Sum of Scores':score_s,
                                'Avg. Weight':wf_m,
                                'Sum of Weights':wf_s})
      
        #display(result) ### To remove
    
    return credit_outcomes

# %%
res = strategies_for_n(4, 50)
# Out:
# Voice Credits: 1
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 2
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 3
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 4
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 5
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 6
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 7
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 8
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 9
# cutoff_strategy None
# wasted_credits_cutoff []
# Voice Credits: 10
# cutoff_strategy [2, 1, 0, 0]
# wasted_credits_cutoff [5]
# Voice Credits: 11
# cutoff_strategy [2, 1, 1, 0]
# wasted_credits_cutoff [5]
# Voice Credits: 12
# cutoff_strategy [2, 1, 1, 1]
# wasted_credits_cutoff [5]
# Voice Credits: 13
# cutoff_strategy [2, 1, 1, 1]
# wasted_credits_cutoff [6]
# Voice Credits: 14
# cutoff_strategy [2, 1, 1, 1]
# wasted_credits_cutoff [7]
# Voice Credits: 15
# cutoff_strategy [2, 1, 1, 1]
# wasted_credits_cutoff [8]
# Voice Credits: 16
# cutoff_strategy [2, 1, 1, 1]
# wasted_credits_cutoff [9]
# Voice Credits: 17
# cutoff_strategy [3, 1, 0, 0]
# wasted_credits_cutoff [7]
# Voice Credits: 18
# cutoff_strategy [3, 1, 1, 0]
# wasted_credits_cutoff [7]
# Voice Credits: 19
# cutoff_strategy [3, 1, 1, 1]
# wasted_credits_cutoff [7]
# Voice Credits: 20
# cutoff_strategy [3, 2, 0, 0]
# wasted_credits_cutoff [7]
# Voice Credits: 21
# cutoff_strategy [3, 2, 1, 0]
# wasted_credits_cutoff [7]
# Voice Credits: 22
# cutoff_strategy [3, 2, 1, 1]
# wasted_credits_cutoff [7]
# Voice Credits: 23
# cutoff_strategy [3, 2, 1, 1]
# wasted_credits_cutoff [8]
# Voice Credits: 24
# cutoff_strategy [3, 2, 2, 0]
# wasted_credits_cutoff [7]
# Voice Credits: 25
# cutoff_strategy [3, 2, 2, 1]
# wasted_credits_cutoff [7]
# Voice Credits: 26
# cutoff_strategy [4, 1, 0, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 27
# cutoff_strategy [4, 1, 1, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 28
# cutoff_strategy [4, 1, 1, 1]
# wasted_credits_cutoff [9]
# Voice Credits: 29
# cutoff_strategy [4, 2, 0, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 30
# cutoff_strategy [4, 2, 1, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 31
# cutoff_strategy [4, 2, 1, 1]
# wasted_credits_cutoff [9]
# Voice Credits: 32
# cutoff_strategy [4, 2, 1, 1]
# wasted_credits_cutoff [10]
# Voice Credits: 33
# cutoff_strategy [4, 2, 2, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 34
# cutoff_strategy [4, 2, 2, 1]
# wasted_credits_cutoff [9]
# Voice Credits: 35
# cutoff_strategy [4, 3, 1, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 36
# cutoff_strategy [4, 3, 1, 1]
# wasted_credits_cutoff [9]
# Voice Credits: 37
# cutoff_strategy [4, 2, 2, 2]
# wasted_credits_cutoff [9]
# Voice Credits: 38
# cutoff_strategy [5, 1, 1, 0]
# wasted_credits_cutoff [11]
# Voice Credits: 39
# cutoff_strategy [4, 3, 2, 1]
# wasted_credits_cutoff [9]
# Voice Credits: 40
# cutoff_strategy [5, 2, 0, 0]
# wasted_credits_cutoff [11]
# Voice Credits: 41
# cutoff_strategy [5, 2, 1, 0]
# wasted_credits_cutoff [11]
# Voice Credits: 42
# cutoff_strategy [4, 3, 2, 2]
# wasted_credits_cutoff [9]
# Voice Credits: 43
# cutoff_strategy [4, 3, 3, 0]
# wasted_credits_cutoff [9]
# Voice Credits: 44
# cutoff_strategy [5, 2, 2, 0]
# wasted_credits_cutoff [11]
# Voice Credits: 45
# cutoff_strategy [5, 2, 2, 1]
# wasted_credits_cutoff [11]
# Voice Credits: 46
# cutoff_strategy [5, 3, 1, 0]
# wasted_credits_cutoff [11]
# Voice Credits: 47
# cutoff_strategy [5, 3, 1, 1]
# wasted_credits_cutoff [11]
# Voice Credits: 48
# cutoff_strategy [5, 2, 2, 2]
# wasted_credits_cutoff [11]
# Voice Credits: 49
# cutoff_strategy [5, 3, 2, 0]
# wasted_credits_cutoff [11]
# Voice Credits: 50
# cutoff_strategy [6, 1, 0, 0]
# wasted_credits_cutoff [13]

# %% [markdown]
# #### .py Test:

# %%
from qv_credit_optimization import strategies_for_n

# %%
strategies_for_n(3,26, display_details = True)
# Out:
# Voice Credits: 1
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 0, 0]               1.0               0            0.0            1.0
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax  WF1  \
# 0           1.0    0.6667                0                  0  1.0
#
#    weighted_score
# 0             0.0
# Voice Credits: 2
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 0, 0]               1.0               1            0.0            0.5
# 1  [1, 1, 0]               1.0               0            0.0            1.0
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax  WF1  \
# 0           0.5   0.33335                0                  0  0.5
# 1           1.0   0.66670                1                  1  1.0
#
#    weighted_score
# 0             0.0
# 1             2.0
# Voice Credits: 3
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 0, 0]               1.0               2            0.0           0.25
# 1  [1, 1, 0]               1.0               1            0.0           0.50
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax   WF1  \
# 0          0.25  0.166675                0                  0  0.25
# 1          0.50  0.333350                1                  1  0.50
#
#    weighted_score
# 0             0.0
# 1             1.0
# Voice Credits: 4
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 1, 0]               1.0               2            0.0           0.25
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax   WF1  \
# 0          0.25  0.166675                0                 -2  0.25
#
#    weighted_score
# 0            -0.5
# Voice Credits: 5
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 1, 0]               1.0               3            0.0          0.125
# 1  [2, 1, 0]               0.6               0            1.0          2.000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax    WF1  \
# 0         0.125  0.083337                0                 -2  0.125
# 1         1.000  1.333300                1                  1  1.000
#
#    weighted_score
# 0           -0.25
# 1            2.00
# Voice Credits: 6
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 1, 0]          1.000000               4            0.0         0.0625
# 1  [2, 0, 0]          0.500000               2            0.0         0.5000
# 2  [2, 1, 0]          0.600000               1            0.5         1.0000
# 3  [2, 1, 1]          0.666667               0            0.0         1.0000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax     WF1  \
# 0        0.0625  0.041669                0                 -2  0.0625
# 1        0.5000  0.333325                0                  0  0.2500
# 2        0.5000  0.666650                1                  1  0.5000
# 3        1.0000  0.666700                2                  2  1.0000
#
#    weighted_score
# 0          -0.125
# 1           0.000
# 2           1.000
# 3           4.000
# Voice Credits: 7
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [1, 1, 0]          1.000000               5           0.00        0.03125
# 1  [2, 0, 0]          0.500000               3           0.00        0.25000
# 2  [2, 1, 0]          0.600000               2           0.25        0.50000
# 3  [2, 1, 1]          0.666667               1           0.00        0.50000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax      WF1  \
# 0       0.03125  0.020834                0                 -2  0.03125
# 1       0.25000  0.166662                0                  0  0.12500
# 2       0.25000  0.333325                1                  1  0.25000
# 3       0.50000  0.333350                2                  2  0.50000
#
#    weighted_score
# 0         -0.0625
# 1          0.0000
# 2          0.5000
# 3          2.0000
# Voice Credits: 8
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [2, 0, 0]          0.500000               4          0.000          0.125
# 1  [2, 1, 0]          0.600000               3          0.125          0.250
# 2  [2, 1, 1]          0.666667               2          0.000          0.250
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax     WF1  \
# 0         0.125  0.083331                0                  0  0.0625
# 1         0.125  0.166662                1                  1  0.1250
# 2         0.250  0.166675                2                  2  0.2500
#
#    weighted_score
# 0            0.00
# 1            0.25
# 2            1.00
# Voice Credits: 9
# cutoff_strategy None
# wasted_credits_cutoff []
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 0  [2, 1, 0]          0.600000               4         0.0625          0.125
# 1  [2, 1, 1]          0.666667               3         0.0000          0.125
# 2  [2, 2, 0]          0.500000               1         0.0000          1.000
# 3  [2, 2, 1]          0.555556               0         0.0000          1.000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax     WF1  \
# 0        0.0625  0.083331                0                 -4  0.0625
# 1        0.1250  0.083337                1                 -3  0.1250
# 2        1.0000  0.666650                1                 -1  0.5000
# 3        1.0000  0.666700                2                  0  1.0000
#
#    weighted_score
# 0           -0.25
# 1           -0.25
# 2            0.00
# 3            2.00
# Voice Credits: 10
# cutoff_strategy [2, 1, 0]
# wasted_credits_cutoff [5]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 1  [2, 1, 1]          0.666667               4            0.0         0.0625
# 2  [2, 2, 0]          0.500000               2            0.0         0.5000
# 3  [2, 2, 1]          0.555556               1            0.0         0.5000
# 4  [3, 1, 0]          0.400000               0            1.0         3.0000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax     WF1  \
# 1        0.0625  0.041669                1                 -3  0.0625
# 2        0.5000  0.333325                1                 -1  0.2500
# 3        0.5000  0.333350                2                  0  0.5000
# 4        2.0000  2.000000                1                  1  1.0000
#
#    weighted_score
# 1          -0.125
# 2           0.000
# 3           1.000
# 4           2.000
# Voice Credits: 11
# cutoff_strategy [2, 1, 1]
# wasted_credits_cutoff [5]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 2  [2, 2, 0]          0.500000               3            0.0           0.25
# 3  [2, 2, 1]          0.555556               2            0.0           0.25
# 4  [3, 0, 0]          0.333333               2            0.0           0.75
# 5  [3, 1, 0]          0.400000               1            0.5           1.50
# 6  [3, 1, 1]          0.454545               0            0.0           2.00
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax    WF1  \
# 2          0.25  0.166662                1                 -1  0.125
# 3          0.25  0.166675                2                  0  0.250
# 4          0.75  0.500000                0                  0  0.250
# 5          1.00  1.000000                1                  1  0.500
# 6          2.00  1.333300                2                  2  1.000
#
#    weighted_score
# 2             0.0
# 3             0.5
# 4             0.0
# 5             1.0
# 6             4.0
# Voice Credits: 12
# cutoff_strategy [2, 1, 1]
# wasted_credits_cutoff [6]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 2  [2, 2, 0]          0.500000               4           0.00          0.125
# 3  [2, 2, 1]          0.555556               3           0.00          0.125
# 4  [3, 0, 0]          0.333333               3           0.00          0.375
# 5  [3, 1, 0]          0.400000               2           0.25          0.750
# 6  [3, 1, 1]          0.454545               1           0.00          1.000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax     WF1  \
# 2         0.125  0.083331                1                 -1  0.0625
# 3         0.125  0.083337                2                  0  0.1250
# 4         0.375  0.250000                0                  0  0.1250
# 5         0.500  0.500000                1                  1  0.2500
# 6         1.000  0.666650                2                  2  0.5000
#
#    weighted_score
# 2            0.00
# 3            0.25
# 4            0.00
# 5            0.50
# 6            2.00
# Voice Credits: 13
# cutoff_strategy [2, 1, 1]
# wasted_credits_cutoff [7]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 2  [2, 2, 0]          0.500000               5          0.000         0.0625
# 3  [2, 2, 1]          0.555556               4          0.000         0.0625
# 4  [3, 0, 0]          0.333333               4          0.000         0.1875
# 5  [3, 1, 0]          0.400000               3          0.125         0.3750
# 6  [3, 1, 1]          0.454545               2          0.000         0.5000
# 7  [3, 2, 0]          0.384615               0          1.000         3.0000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax      WF1  \
# 2        0.0625  0.041666                1                 -1  0.03125
# 3        0.0625  0.041669                2                  0  0.06250
# 4        0.1875  0.125000                0                  0  0.06250
# 5        0.2500  0.250000                1                  1  0.12500
# 6        0.5000  0.333325                2                  2  0.25000
# 7        2.0000  2.000000                2                  4  1.00000
#
#    weighted_score
# 2           0.000
# 3           0.125
# 4           0.000
# 5           0.250
# 6           1.000
# 7           6.000
# Voice Credits: 14
# cutoff_strategy [2, 1, 1]
# wasted_credits_cutoff [8]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 1  [2, 2, 0]          0.500000               6         0.0000        0.03125
# 2  [2, 2, 1]          0.555556               5         0.0000        0.03125
# 3  [3, 0, 0]          0.333333               5         0.0000        0.09375
# 4  [3, 1, 0]          0.400000               4         0.0625        0.18750
# 5  [3, 1, 1]          0.454545               3         0.0000        0.25000
# 6  [3, 2, 0]          0.384615               1         0.5000        1.50000
# 7  [3, 2, 1]          0.428571               0         1.0000        2.00000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 1       0.03125  0.020833                1                 -1  0.015625
# 2       0.03125  0.020834                2                  0  0.031250
# 3       0.09375  0.062500                0                  0  0.031250
# 4       0.12500  0.125000                1                  1  0.062500
# 5       0.25000  0.166662                2                  2  0.125000
# 6       1.00000  1.000000                2                  4  0.500000
# 7       1.00000  1.333300                3                  5  1.000000
#
#    weighted_score
# 1          0.0000
# 2          0.0625
# 3          0.0000
# 4          0.1250
# 5          0.5000
# 6          3.0000
# 7          8.0000
# Voice Credits: 15
# cutoff_strategy [2, 1, 1]
# wasted_credits_cutoff [9]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 1  [2, 2, 0]          0.500000               7        0.00000       0.015625
# 2  [2, 2, 1]          0.555556               6        0.00000       0.015625
# 3  [3, 0, 0]          0.333333               6        0.00000       0.046875
# 4  [3, 1, 0]          0.400000               5        0.03125       0.093750
# 5  [3, 1, 1]          0.454545               4        0.00000       0.125000
# 6  [3, 2, 0]          0.384615               2        0.25000       0.750000
# 7  [3, 2, 1]          0.428571               1        0.50000       1.000000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 1      0.015625  0.010416                1                 -1  0.007812
# 2      0.015625  0.010417                2                  0  0.015625
# 3      0.046875  0.031250                0                  0  0.015625
# 4      0.062500  0.062500                1                  1  0.031250
# 5      0.125000  0.083331                2                  2  0.062500
# 6      0.500000  0.500000                2                  4  0.250000
# 7      0.500000  0.666650                3                  5  0.500000
#
#    weighted_score
# 1         0.00000
# 2         0.03125
# 3         0.00000
# 4         0.06250
# 5         0.25000
# 6         1.50000
# 7         4.00000
# Voice Credits: 16
# cutoff_strategy [2, 1, 1]
# wasted_credits_cutoff [10]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 1  [2, 2, 0]          0.500000               8       0.000000       0.007812
# 2  [2, 2, 1]          0.555556               7       0.000000       0.007812
# 3  [3, 1, 0]          0.400000               6       0.015625       0.046875
# 4  [3, 1, 1]          0.454545               5       0.000000       0.062500
# 5  [3, 2, 0]          0.384615               3       0.125000       0.375000
# 6  [3, 2, 1]          0.428571               2       0.250000       0.500000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 1      0.007812  0.005208                0                 -8  0.003906
# 2      0.007812  0.005209                1                 -7  0.007812
# 3      0.031250  0.031250                0                 -6  0.015625
# 4      0.062500  0.041666                1                 -5  0.031250
# 5      0.250000  0.250000                1                 -3  0.125000
# 6      0.250000  0.333325                2                 -2  0.250000
#
#    weighted_score
# 1       -0.031250
# 2       -0.046875
# 3       -0.093750
# 4       -0.125000
# 5       -0.250000
# 6        0.000000
# Voice Credits: 17
# cutoff_strategy [3, 1, 0]
# wasted_credits_cutoff [7]
#     strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 3  [3, 1, 1]          0.454545               6         0.0000        0.03125
# 4  [3, 2, 0]          0.384615               4         0.0625        0.18750
# 5  [3, 2, 1]          0.428571               3         0.1250        0.25000
# 6  [4, 1, 0]          0.294118               0         1.0000        4.00000
# 7  [3, 2, 2]          0.411765               0         0.0000        1.00000
#
#    max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 3       0.03125  0.020833                1                 -5  0.015625
# 4       0.12500  0.125000                1                 -3  0.062500
# 5       0.12500  0.166662                2                 -2  0.125000
# 6       3.00000  2.666700                1                  1  1.000000
# 7       1.00000  0.666700                3                  1  1.000000
#
#    weighted_score
# 3         -0.0625
# 4         -0.1250
# 5          0.0000
# 6          2.0000
# 7          4.0000
# Voice Credits: 18
# cutoff_strategy [3, 1, 1]
# wasted_credits_cutoff [7]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 4   [3, 2, 0]          0.384615               5        0.03125        0.09375
# 5   [3, 2, 1]          0.428571               4        0.06250        0.12500
# 6   [4, 0, 0]          0.250000               2        0.00000        1.00000
# 7   [4, 1, 0]          0.294118               1        0.50000        2.00000
# 8   [3, 2, 2]          0.411765               1        0.00000        0.50000
# 9   [3, 3, 0]          0.333333               0        0.00000        3.00000
# 10  [4, 1, 1]          0.333333               0        0.00000        3.00000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax      WF1  \
# 4         0.0625  0.062500                1                 -3  0.03125
# 5         0.0625  0.083331                2                 -2  0.06250
# 6         1.0000  0.666675                0                  0  0.25000
# 7         1.5000  1.333350                1                  1  0.50000
# 8         0.5000  0.333350                3                  1  0.50000
# 9         3.0000  2.000000                2                  2  1.00000
# 10        3.0000  2.000000                2                  2  1.00000
#
#     weighted_score
# 4          -0.0625
# 5           0.0000
# 6           0.0000
# 7           1.0000
# 8           2.0000
# 9           4.0000
# 10          4.0000
# Voice Credits: 19
# cutoff_strategy [3, 1, 1]
# wasted_credits_cutoff [8]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 3   [3, 2, 0]          0.384615               6       0.015625       0.046875
# 4   [3, 2, 1]          0.428571               5       0.031250       0.062500
# 5   [4, 0, 0]          0.250000               3       0.000000       0.500000
# 6   [4, 1, 0]          0.294118               2       0.250000       1.000000
# 7   [3, 2, 2]          0.411765               2       0.000000       0.250000
# 8   [3, 3, 0]          0.333333               1       0.000000       1.500000
# 9   [4, 1, 1]          0.333333               1       0.000000       1.500000
# 10  [3, 3, 1]          0.368421               0       0.000000       2.000000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 3        0.03125  0.031250                1                 -3  0.015625
# 4        0.03125  0.041666                2                 -2  0.031250
# 5        0.50000  0.333338                0                  0  0.125000
# 6        0.75000  0.666675                1                  1  0.250000
# 7        0.25000  0.166675                3                  1  0.250000
# 8        1.50000  1.000000                2                  2  0.500000
# 9        1.50000  1.000000                2                  2  0.500000
# 10       2.00000  1.333300                3                  3  1.000000
#
#     weighted_score
# 3         -0.03125
# 4          0.00000
# 5          0.00000
# 6          0.50000
# 7          1.00000
# 8          2.00000
# 9          2.00000
# 10         6.00000
# Voice Credits: 20
# cutoff_strategy [3, 2, 0]
# wasted_credits_cutoff [7]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 4   [3, 2, 1]          0.428571               6       0.015625        0.03125
# 5   [4, 0, 0]          0.250000               4       0.000000        0.25000
# 6   [4, 1, 0]          0.294118               3       0.125000        0.50000
# 7   [3, 2, 2]          0.411765               3       0.000000        0.12500
# 8   [3, 3, 0]          0.333333               2       0.000000        0.75000
# 9   [4, 1, 1]          0.333333               2       0.000000        0.75000
# 10  [3, 3, 1]          0.368421               1       0.000000        1.00000
# 11  [4, 2, 0]          0.300000               0       2.000000        4.00000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 4       0.015625  0.020833                2                 -2  0.015625
# 5       0.250000  0.166669                0                  0  0.062500
# 6       0.375000  0.333338                1                  1  0.125000
# 7       0.125000  0.083337                3                  1  0.125000
# 8       0.750000  0.500000                2                  2  0.250000
# 9       0.750000  0.500000                2                  2  0.250000
# 10      1.000000  0.666650                3                  3  0.500000
# 11      2.000000  2.666700                2                  4  1.000000
#
#     weighted_score
# 4             0.00
# 5             0.00
# 6             0.25
# 7             0.50
# 8             1.00
# 9             1.00
# 10            3.00
# 11            6.00
# Voice Credits: 21
# cutoff_strategy [3, 2, 1]
# wasted_credits_cutoff [7]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 4   [4, 0, 0]          0.250000               5         0.0000         0.1250
# 5   [4, 1, 0]          0.294118               4         0.0625         0.2500
# 6   [3, 2, 2]          0.411765               4         0.0000         0.0625
# 7   [3, 3, 0]          0.333333               3         0.0000         0.3750
# 8   [4, 1, 1]          0.333333               3         0.0000         0.3750
# 9   [3, 3, 1]          0.368421               2         0.0000         0.5000
# 10  [4, 2, 0]          0.300000               1         1.0000         2.0000
# 11  [4, 2, 1]          0.333333               0         1.0000         3.0000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax      WF1  \
# 4         0.1250  0.083334                0                  0  0.03125
# 5         0.1875  0.166669                1                  1  0.06250
# 6         0.0625  0.041669                3                  1  0.06250
# 7         0.3750  0.250000                2                  2  0.12500
# 8         0.3750  0.250000                2                  2  0.12500
# 9         0.5000  0.333325                3                  3  0.25000
# 10        1.0000  1.333350                2                  4  0.50000
# 11        2.0000  2.000000                3                  5  1.00000
#
#     weighted_score
# 4            0.000
# 5            0.125
# 6            0.250
# 7            0.500
# 8            0.500
# 9            1.500
# 10           3.000
# 11           8.000
# Voice Credits: 22
# cutoff_strategy [3, 2, 1]
# wasted_credits_cutoff [8]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 3   [4, 0, 0]          0.250000               6        0.00000        0.06250
# 4   [4, 1, 0]          0.294118               5        0.03125        0.12500
# 5   [3, 2, 2]          0.411765               5        0.00000        0.03125
# 6   [3, 3, 0]          0.333333               4        0.00000        0.18750
# 7   [4, 1, 1]          0.333333               4        0.00000        0.18750
# 8   [3, 3, 1]          0.368421               3        0.00000        0.25000
# 9   [4, 2, 0]          0.300000               2        0.50000        1.00000
# 10  [4, 2, 1]          0.333333               1        0.50000        1.50000
# 11  [3, 3, 2]          0.363636               0        0.00000        1.00000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 3        0.06250  0.041667                0                  0  0.015625
# 4        0.09375  0.083334                1                  1  0.031250
# 5        0.03125  0.020834                3                  1  0.031250
# 6        0.18750  0.125000                2                  2  0.062500
# 7        0.18750  0.125000                2                  2  0.062500
# 8        0.25000  0.166662                3                  3  0.125000
# 9        0.50000  0.666675                2                  4  0.250000
# 10       1.00000  1.000000                3                  5  0.500000
# 11       1.00000  0.666700                4                  6  1.000000
#
#     weighted_score
# 3           0.0000
# 4           0.0625
# 5           0.1250
# 6           0.2500
# 7           0.2500
# 8           0.7500
# 9           1.5000
# 10          4.0000
# 11         10.0000
# Voice Credits: 23
# cutoff_strategy [3, 2, 1]
# wasted_credits_cutoff [9]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 3   [4, 0, 0]          0.250000               7       0.000000       0.031250
# 4   [4, 1, 0]          0.294118               6       0.015625       0.062500
# 5   [3, 2, 2]          0.411765               6       0.000000       0.015625
# 6   [3, 3, 0]          0.333333               5       0.000000       0.093750
# 7   [4, 1, 1]          0.333333               5       0.000000       0.093750
# 8   [3, 3, 1]          0.368421               4       0.000000       0.125000
# 9   [4, 2, 0]          0.300000               3       0.250000       0.500000
# 10  [4, 2, 1]          0.333333               2       0.250000       0.750000
# 11  [3, 3, 2]          0.363636               1       0.000000       0.500000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 3       0.031250  0.020834                0                  0  0.007812
# 4       0.046875  0.041667                1                  1  0.015625
# 5       0.015625  0.010417                3                  1  0.015625
# 6       0.093750  0.062500                2                  2  0.031250
# 7       0.093750  0.062500                2                  2  0.031250
# 8       0.125000  0.083331                3                  3  0.062500
# 9       0.250000  0.333338                2                  4  0.125000
# 10      0.500000  0.500000                3                  5  0.250000
# 11      0.500000  0.333350                4                  6  0.500000
#
#     weighted_score
# 3          0.00000
# 4          0.03125
# 5          0.06250
# 6          0.12500
# 7          0.12500
# 8          0.37500
# 9          0.75000
# 10         2.00000
# 11         5.00000
# Voice Credits: 24
# cutoff_strategy [3, 2, 2]
# wasted_credits_cutoff [7]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 5   [3, 3, 0]          0.333333               6          0.000       0.046875
# 6   [4, 1, 1]          0.333333               6          0.000       0.046875
# 7   [3, 3, 1]          0.368421               5          0.000       0.062500
# 8   [4, 2, 0]          0.300000               4          0.125       0.250000
# 9   [4, 2, 1]          0.333333               3          0.125       0.375000
# 10  [3, 3, 2]          0.363636               2          0.000       0.250000
# 11  [4, 2, 2]          0.333333               0          0.000       2.000000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 5       0.046875  0.031250                2                  2  0.015625
# 6       0.046875  0.031250                2                  2  0.015625
# 7       0.062500  0.041666                3                  3  0.031250
# 8       0.125000  0.166669                2                  4  0.062500
# 9       0.250000  0.250000                3                  5  0.125000
# 10      0.250000  0.166675                4                  6  0.250000
# 11      2.000000  1.333300                4                  8  1.000000
#
#     weighted_score
# 5           0.0625
# 6           0.0625
# 7           0.1875
# 8           0.3750
# 9           1.0000
# 10          2.5000
# 11         12.0000
# Voice Credits: 25
# cutoff_strategy [3, 2, 2]
# wasted_credits_cutoff [8]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 4   [3, 3, 0]          0.333333               7         0.0000       0.023438
# 5   [4, 1, 1]          0.333333               7         0.0000       0.023438
# 6   [3, 3, 1]          0.368421               6         0.0000       0.031250
# 7   [4, 2, 0]          0.300000               5         0.0625       0.125000
# 8   [4, 2, 1]          0.333333               4         0.0625       0.187500
# 9   [3, 3, 2]          0.363636               3         0.0000       0.125000
# 10  [4, 2, 2]          0.333333               1         0.0000       1.000000
# 11  [4, 3, 0]          0.280000               0         1.0000       4.000000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 4       0.023438  0.015625                1                 -7  0.007812
# 5       0.023438  0.015625                1                 -7  0.007812
# 6       0.031250  0.020833                2                 -6  0.015625
# 7       0.062500  0.083334                1                 -5  0.031250
# 8       0.125000  0.125000                2                 -4  0.062500
# 9       0.125000  0.083337                3                 -3  0.125000
# 10      1.000000  0.666650                3                 -1  0.500000
# 11      3.000000  2.666700                2                  0  1.000000
#
#     weighted_score
# 4        -0.046875
# 5        -0.046875
# 6        -0.062500
# 7        -0.125000
# 8        -0.125000
# 9         0.000000
# 10        1.000000
# 11        2.000000
# Voice Credits: 26
# cutoff_strategy [4, 1, 0]
# wasted_credits_cutoff [9]
#      strategy  votes per credit  wasted_credits  min_vote_diff  max_vote_diff  \
# 3   [3, 3, 0]          0.333333               8        0.00000       0.011719
# 4   [4, 1, 1]          0.333333               8        0.00000       0.011719
# 5   [3, 3, 1]          0.368421               7        0.00000       0.015625
# 6   [4, 2, 0]          0.300000               6        0.03125       0.062500
# 7   [4, 2, 1]          0.333333               5        0.03125       0.093750
# 8   [3, 3, 2]          0.363636               4        0.00000       0.062500
# 9   [4, 2, 2]          0.333333               2        0.00000       0.500000
# 10  [4, 3, 0]          0.280000               1        0.50000       2.000000
# 11  [4, 3, 1]          0.307692               0        1.00000       3.000000
# 12  [5, 1, 0]          0.230769               0        1.00000       5.000000
#
#     max_min_diff  avg_diff  votes_over_vmax  credits_over_vmax       WF1  \
# 3       0.011719  0.007812                1                 -7  0.003906
# 4       0.011719  0.007812                1                 -7  0.003906
# 5       0.015625  0.010416                2                 -6  0.007812
# 6       0.031250  0.041667                1                 -5  0.015625
# 7       0.062500  0.062500                2                 -4  0.031250
# 8       0.062500  0.041669                3                 -3  0.062500
# 9       0.500000  0.333325                3                 -1  0.250000
# 10      1.500000  1.333350                2                  0  0.500000
# 11      2.000000  2.000000                3                  1  1.000000
# 12      4.000000  3.333300                1                  1  1.000000
#
#     weighted_score
# 3        -0.023438
# 4        -0.023438
# 5        -0.031250
# 6        -0.062500
# 7        -0.062500
# 8         0.000000
# 9         0.500000
# 10        1.000000
# 11        4.000000
# 12        2.000000
# [{'Credits': 1,
#   'Strategies': 1,
#   'Votes per Credit': 1.0,
#   'Total Wasted Credits': 0,
#   'Avg. Wasted Credits per Strategy': 0.0,
#   'Avg. Min Vote Diff': 0.0,
#   'Avg. Max Vote Diff': 1.0,
#   'Avg. MinMax Vote Diff': 1.0,
#   'Avg. Diff': 0.6667,
#   'Avg. Score': 0.0,
#   'Sum of Scores': 0.0,
#   'Avg. Weight': 1.0,
#   'Sum of Weights': 1.0},
#  {'Credits': 2,
#   'Strategies': 2,
#   'Votes per Credit': 1.0,
#   'Total Wasted Credits': 1,
#   'Avg. Wasted Credits per Strategy': 0.5,
#   'Avg. Min Vote Diff': 0.0,
#   'Avg. Max Vote Diff': 0.75,
#   'Avg. MinMax Vote Diff': 0.75,
#   'Avg. Diff': 0.5000249999999999,
#   'Avg. Score': 1.0,
#   'Sum of Scores': 2.0,
#   'Avg. Weight': 0.75,
#   'Sum of Weights': 1.5},
#  {'Credits': 3,
#   'Strategies': 2,
#   'Votes per Credit': 1.0,
#   'Total Wasted Credits': 3,
#   'Avg. Wasted Credits per Strategy': 1.5,
#   'Avg. Min Vote Diff': 0.0,
#   'Avg. Max Vote Diff': 0.375,
#   'Avg. MinMax Vote Diff': 0.375,
#   'Avg. Diff': 0.25001249999999997,
#   'Avg. Score': 0.5,
#   'Sum of Scores': 1.0,
#   'Avg. Weight': 0.375,
#   'Sum of Weights': 0.75},
#  {'Credits': 4,
#   'Strategies': 1,
#   'Votes per Credit': 1.0,
#   'Total Wasted Credits': 2,
#   'Avg. Wasted Credits per Strategy': 2.0,
#   'Avg. Min Vote Diff': 0.0,
#   'Avg. Max Vote Diff': 0.25,
#   'Avg. MinMax Vote Diff': 0.25,
#   'Avg. Diff': 0.166675,
#   'Avg. Score': -0.5,
#   'Sum of Scores': -0.5,
#   'Avg. Weight': 0.25,
#   'Sum of Weights': 0.25},
#  {'Credits': 5,
#   'Strategies': 2,
#   'Votes per Credit': 0.8,
#   'Total Wasted Credits': 3,
#   'Avg. Wasted Credits per Strategy': 1.5,
#   'Avg. Min Vote Diff': 0.5,
#   'Avg. Max Vote Diff': 1.0625,
#   'Avg. MinMax Vote Diff': 0.5625,
#   'Avg. Diff': 0.70831875,
#   'Avg. Score': 0.875,
#   'Sum of Scores': 1.75,
#   'Avg. Weight': 0.5625,
#   'Sum of Weights': 1.125},
#  {'Credits': 6,
#   'Strategies': 4,
#   'Votes per Credit': 0.6916666666666667,
#   'Total Wasted Credits': 7,
#   'Avg. Wasted Credits per Strategy': 1.75,
#   'Avg. Min Vote Diff': 0.125,
#   'Avg. Max Vote Diff': 0.640625,
#   'Avg. MinMax Vote Diff': 0.515625,
#   'Avg. Diff': 0.4270859375,
#   'Avg. Score': 1.21875,
#   'Sum of Scores': 4.875,
#   'Avg. Weight': 0.453125,
#   'Sum of Weights': 1.8125},
#  {'Credits': 7,
#   'Strategies': 4,
#   'Votes per Credit': 0.6916666666666667,
#   'Total Wasted Credits': 11,
#   'Avg. Wasted Credits per Strategy': 2.75,
#   'Avg. Min Vote Diff': 0.0625,
#   'Avg. Max Vote Diff': 0.3203125,
#   'Avg. MinMax Vote Diff': 0.2578125,
#   'Avg. Diff': 0.21354296875,
#   'Avg. Score': 0.609375,
#   'Sum of Scores': 2.4375,
#   'Avg. Weight': 0.2265625,
#   'Sum of Weights': 0.90625},
#  {'Credits': 8,
#   'Strategies': 3,
#   'Votes per Credit': 0.5888888888888889,
#   'Total Wasted Credits': 9,
#   'Avg. Wasted Credits per Strategy': 3.0,
#   'Avg. Min Vote Diff': 0.041666666666666664,
#   'Avg. Max Vote Diff': 0.20833333333333334,
#   'Avg. MinMax Vote Diff': 0.16666666666666666,
#   'Avg. Diff': 0.13888958333333332,
#   'Avg. Score': 0.4166666666666667,
#   'Sum of Scores': 1.25,
#   'Avg. Weight': 0.14583333333333334,
#   'Sum of Weights': 0.4375},
#  {'Credits': 9,
#   'Strategies': 4,
#   'Votes per Credit': 0.5805555555555555,
#   'Total Wasted Credits': 8,
#   'Avg. Wasted Credits per Strategy': 2.0,
#   'Avg. Min Vote Diff': 0.015625,
#   'Avg. Max Vote Diff': 0.5625,
#   'Avg. MinMax Vote Diff': 0.546875,
#   'Avg. Diff': 0.37500468749999993,
#   'Avg. Score': 0.375,
#   'Sum of Scores': 1.5,
#   'Avg. Weight': 0.421875,
#   'Sum of Weights': 1.6875},
#  {'Credits': 10,
#   'Strategies': 4,
#   'Votes per Credit': 0.5305555555555556,
#   'Total Wasted Credits': 7,
#   'Avg. Wasted Credits per Strategy': 1.75,
#   'Avg. Min Vote Diff': 0.25,
#   'Avg. Max Vote Diff': 1.015625,
#   'Avg. MinMax Vote Diff': 0.765625,
#   'Avg. Diff': 0.6770859375,
#   'Avg. Score': 0.71875,
#   'Sum of Scores': 2.875,
#   'Avg. Weight': 0.453125,
#   'Sum of Weights': 1.8125},
#  {'Credits': 11,
#   'Strategies': 5,
#   'Votes per Credit': 0.4486868686868687,
#   'Total Wasted Credits': 8,
#   'Avg. Wasted Credits per Strategy': 1.6,
#   'Avg. Min Vote Diff': 0.1,
#   'Avg. Max Vote Diff': 0.95,
#   'Avg. MinMax Vote Diff': 0.85,
#   'Avg. Diff': 0.6333274999999999,
#   'Avg. Score': 1.1,
#   'Sum of Scores': 5.5,
#   'Avg. Weight': 0.425,
#   'Sum of Weights': 2.125},
#  {'Credits': 12,
#   'Strategies': 5,
#   'Votes per Credit': 0.4486868686868687,
#   'Total Wasted Credits': 13,
#   'Avg. Wasted Credits per Strategy': 2.6,
#   'Avg. Min Vote Diff': 0.05,
#   'Avg. Max Vote Diff': 0.475,
#   'Avg. MinMax Vote Diff': 0.425,
#   'Avg. Diff': 0.31666374999999997,
#   'Avg. Score': 0.55,
#   'Sum of Scores': 2.75,
#   'Avg. Weight': 0.2125,
#   'Sum of Weights': 1.0625},
#  {'Credits': 13,
#   'Strategies': 6,
#   'Votes per Credit': 0.438008288008288,
#   'Total Wasted Credits': 18,
#   'Avg. Wasted Credits per Strategy': 3.0,
#   'Avg. Min Vote Diff': 0.1875,
#   'Avg. Max Vote Diff': 0.6979166666666666,
#   'Avg. MinMax Vote Diff': 0.5104166666666666,
#   'Avg. Diff': 0.4652765625,
#   'Avg. Score': 1.2291666666666667,
#   'Sum of Scores': 7.375,
#   'Avg. Weight': 0.2552083333333333,
#   'Sum of Weights': 1.53125},
#  {'Credits': 14,
#   'Strategies': 7,
#   'Votes per Credit': 0.43666016523159373,
#   'Total Wasted Credits': 24,
#   'Avg. Wasted Credits per Strategy': 3.4285714285714284,
#   'Avg. Min Vote Diff': 0.22321428571428573,
#   'Avg. Max Vote Diff': 0.5848214285714286,
#   'Avg. MinMax Vote Diff': 0.36160714285714285,
#   'Avg. Diff': 0.38987566964285714,
#   'Avg. Score': 1.6696428571428572,
#   'Sum of Scores': 11.6875,
#   'Avg. Weight': 0.25223214285714285,
#   'Sum of Weights': 1.765625},
#  {'Credits': 15,
#   'Strategies': 7,
#   'Votes per Credit': 0.43666016523159373,
#   'Total Wasted Credits': 31,
#   'Avg. Wasted Credits per Strategy': 4.428571428571429,
#   'Avg. Min Vote Diff': 0.11160714285714286,
#   'Avg. Max Vote Diff': 0.2924107142857143,
#   'Avg. MinMax Vote Diff': 0.18080357142857142,
#   'Avg. Diff': 0.19493783482142857,
#   'Avg. Score': 0.8348214285714286,
#   'Sum of Scores': 5.84375,
#   'Avg. Weight': 0.12611607142857142,
#   'Sum of Weights': 0.8828125},
#  {'Credits': 16,
#   'Strategies': 6,
#   'Votes per Credit': 0.4538813038813039,
#   'Total Wasted Credits': 31,
#   'Avg. Wasted Credits per Strategy': 5.166666666666667,
#   'Avg. Min Vote Diff': 0.06510416666666667,
#   'Avg. Max Vote Diff': 0.16666666666666666,
#   'Avg. MinMax Vote Diff': 0.1015625,
#   'Avg. Diff': 0.1111095703125,
#   'Avg. Score': -0.09114583333333333,
#   'Sum of Scores': -0.546875,
#   'Avg. Weight': 0.072265625,
#   'Sum of Weights': 0.43359375},
#  {'Credits': 17,
#   'Strategies': 5,
#   'Votes per Credit': 0.39472292413468885,
#   'Total Wasted Credits': 13,
#   'Avg. Wasted Credits per Strategy': 2.6,
#   'Avg. Min Vote Diff': 0.2375,
#   'Avg. Max Vote Diff': 1.09375,
#   'Avg. MinMax Vote Diff': 0.85625,
#   'Avg. Diff': 0.7291790625,
#   'Avg. Score': 1.1625,
#   'Sum of Scores': 5.8125,
#   'Avg. Weight': 0.440625,
#   'Sum of Weights': 2.203125},
#  {'Credits': 18,
#   'Strategies': 7,
#   'Votes per Credit': 0.3479622618278081,
#   'Total Wasted Credits': 13,
#   'Avg. Wasted Credits per Strategy': 1.8571428571428572,
#   'Avg. Min Vote Diff': 0.08482142857142858,
#   'Avg. Max Vote Diff': 1.3883928571428572,
#   'Avg. MinMax Vote Diff': 1.3035714285714286,
#   'Avg. Diff': 0.9256008928571429,
#   'Avg. Score': 1.5625,
#   'Sum of Scores': 10.9375,
#   'Avg. Weight': 0.47767857142857145,
#   'Sum of Weights': 3.34375},
#  {'Credits': 19,
#   'Strategies': 8,
#   'Votes per Credit': 0.3505196106782794,
#   'Total Wasted Credits': 20,
#   'Avg. Wasted Credits per Strategy': 2.5,
#   'Avg. Min Vote Diff': 0.037109375,
#   'Avg. Max Vote Diff': 0.857421875,
#   'Avg. MinMax Vote Diff': 0.8203125,
#   'Avg. Diff': 0.571612890625,
#   'Avg. Score': 1.43359375,
#   'Sum of Scores': 11.46875,
#   'Avg. Weight': 0.333984375,
#   'Sum of Weights': 2.671875},
#  {'Credits': 20,
#   'Strategies': 8,
#   'Votes per Credit': 0.33994268760135626,
#   'Total Wasted Credits': 21,
#   'Avg. Wasted Credits per Strategy': 2.625,
#   'Avg. Min Vote Diff': 0.267578125,
#   'Avg. Max Vote Diff': 0.92578125,
#   'Avg. MinMax Vote Diff': 0.658203125,
#   'Avg. Diff': 0.6171908203125,
#   'Avg. Score': 1.46875,
#   'Sum of Scores': 11.75,
#   'Avg. Weight': 0.291015625,
#   'Sum of Weights': 2.328125},
#  {'Credits': 21,
#   'Strategies': 8,
#   'Votes per Credit': 0.32803792569659446,
#   'Total Wasted Credits': 22,
#   'Avg. Wasted Credits per Strategy': 2.75,
#   'Avg. Min Vote Diff': 0.2578125,
#   'Avg. Max Vote Diff': 0.8359375,
#   'Avg. MinMax Vote Diff': 0.578125,
#   'Avg. Diff': 0.557293359375,
#   'Avg. Score': 1.734375,
#   'Sum of Scores': 13.875,
#   'Avg. Weight': 0.26953125,
#   'Sum of Weights': 2.15625},
#  {'Credits': 22,
#   'Strategies': 9,
#   'Votes per Credit': 0.33199330768990215,
#   'Total Wasted Credits': 30,
#   'Avg. Wasted Credits per Strategy': 3.3333333333333335,
#   'Avg. Min Vote Diff': 0.11458333333333333,
#   'Avg. Max Vote Diff': 0.4826388888888889,
#   'Avg. MinMax Vote Diff': 0.3680555555555556,
#   'Avg. Diff': 0.3217637152777778,
#   'Avg. Score': 1.8819444444444444,
#   'Sum of Scores': 16.9375,
#   'Avg. Weight': 0.2309027777777778,
#   'Sum of Weights': 2.078125},
#  {'Credits': 23,
#   'Strategies': 9,
#   'Votes per Credit': 0.33199330768990215,
#   'Total Wasted Credits': 39,
#   'Avg. Wasted Credits per Strategy': 4.333333333333333,
#   'Avg. Min Vote Diff': 0.057291666666666664,
#   'Avg. Max Vote Diff': 0.24131944444444445,
#   'Avg. MinMax Vote Diff': 0.1840277777777778,
#   'Avg. Diff': 0.1608818576388889,
#   'Avg. Score': 0.9409722222222222,
#   'Sum of Scores': 8.46875,
#   'Avg. Weight': 0.1154513888888889,
#   'Sum of Weights': 1.0390625},
#  {'Credits': 24,
#   'Strategies': 7,
#   'Votes per Credit': 0.33791296422875367,
#   'Total Wasted Credits': 26,
#   'Avg. Wasted Credits per Strategy': 3.7142857142857144,
#   'Avg. Min Vote Diff': 0.03571428571428571,
#   'Avg. Max Vote Diff': 0.4330357142857143,
#   'Avg. MinMax Vote Diff': 0.39732142857142855,
#   'Avg. Diff': 0.28868705357142854,
#   'Avg. Score': 2.3125,
#   'Sum of Scores': 16.1875,
#   'Avg. Weight': 0.21428571428571427,
#   'Sum of Weights': 1.5},
#  {'Credits': 25,
#   'Strategies': 8,
#   'Votes per Credit': 0.3306738437001595,
#   'Total Wasted Credits': 33,
#   'Avg. Wasted Credits per Strategy': 4.125,
#   'Avg. Min Vote Diff': 0.140625,
#   'Avg. Max Vote Diff': 0.689453125,
#   'Avg. MinMax Vote Diff': 0.548828125,
#   'Avg. Diff': 0.4596380859375,
#   'Avg. Score': 0.32421875,
#   'Sum of Scores': 2.59375,
#   'Avg. Weight': 0.21875,
#   'Sum of Weights': 1.75},
#  {'Credits': 26,
#   'Strategies': 10,
#   'Votes per Credit': 0.31838522880628145,
#   'Total Wasted Credits': 41,
#   'Avg. Wasted Credits per Strategy': 4.1,
#   'Avg. Min Vote Diff': 0.25625,
#   'Avg. Max Vote Diff': 1.07578125,
#   'Avg. MinMax Vote Diff': 0.81953125,
#   'Avg. Diff': 0.717185234375,
#   'Avg. Score': 0.7296875,
#   'Sum of Scores': 7.296875,
#   'Avg. Weight': 0.2875,
#   'Sum of Weights': 2.875}]

# %% [markdown]
# ##### TO INVESTIGATE: Various weight factors and metrics

# %% [markdown]
# ## STEP 4: Compare all strategy sets for a given N to determine which value of C is optimal

# %% [markdown]
# ### 4a. Build analysis dataframe for N and an arbitrary Cmax, with metrics for each C.

# %%
res = pd.DataFrame(res)
res
# Out:
#     Credits  Strategies  Votes per Credit  Total Wasted Credits  \
# 0         1           1          1.000000                     0
# 1         2           2          1.000000                     1
# 2         3           3          1.000000                     3
# 3         4           2          1.000000                     3
# 4         5           3          0.866667                     5
# 5         6           4          0.816667                     8
# 6         7           6          0.746825                    15
# 7         8           5          0.696190                    15
# 8         9           5          0.707302                    15
# 9        10           6          0.572751                    10
# 10       11           6          0.537398                    11
# 11       12           7          0.477633                    15
# 12       13          10          0.476651                    23
# 13       14          11          0.472280                    33
# 14       15          12          0.471812                    44
# 15       16          11          0.484401                    49
# 16       17           9          0.442083                    29
# 17       18          11          0.421392                    31
# 18       19          12          0.385179                    31
# 19       20          12          0.366589                    29
# 20       21          13          0.364031                    34
# 21       22          14          0.356644                    40
# 22       23          15          0.358954                    54
# 23       24          13          0.366290                    47
# 24       25          12          0.357555                    39
# 25       26          18          0.351380                    75
# 26       27          18          0.341092                    66
# 27       28          20          0.330141                    69
# 28       29          20          0.322727                    71
# 29       30          20          0.314632                    73
# 30       31          20          0.310526                    75
# 31       32          21          0.307644                    95
# 32       33          22          0.300667                    97
# 33       34          23          0.299666                    92
# 34       35          22          0.297303                    88
# 35       36          21          0.293824                    83
# 36       37          21          0.283528                    77
# 37       38          27          0.286799                   128
# 38       39          23          0.272666                    87
# 39       40          27          0.273012                   130
# 40       41          28          0.267094                   135
# 41       42          26          0.259704                   104
# 42       43          25          0.257945                    94
# 43       44          31          0.260202                   159
# 44       45          31          0.255690                   146
# 45       46          31          0.252685                   155
# 46       47          30          0.254055                   153
# 47       48          29          0.253030                   150
# 48       49          29          0.251844                   146
# 49       50          36          0.250360                   211
#
#     Avg. Wasted Credits per Strategy  Avg. Min Vote Diff  Avg. Max Vote Diff  \
# 0                           0.000000            0.000000            1.000000
# 1                           0.500000            0.000000            0.750000
# 2                           1.000000            0.000000            0.583333
# 3                           1.500000            0.000000            0.375000
# 4                           1.666667            0.000000            0.791667
# 5                           2.000000            0.000000            0.796875
# 6                           2.500000            0.000000            0.473958
# 7                           3.000000            0.000000            0.281250
# 8                           3.000000            0.000000            0.528125
# 9                           1.666667            0.000000            0.958333
# 10                          1.833333            0.000000            0.968750
# 11                          2.142857            0.000000            0.750000
# 12                          2.300000            0.000000            0.762500
# 13                          3.000000            0.090909            0.619318
# 14                          3.666667            0.041667            0.450521
# 15                          4.454545            0.022727            0.243608
# 16                          3.222222            0.013889            0.921875
# 17                          2.818182            0.005682            1.193182
# 18                          2.583333            0.002604            1.085938
# 19                          2.416667            0.001302            1.040365
# 20                          2.615385            0.076923            0.862981
# 21                          2.857143            0.035714            0.828125
# 22                          3.600000            0.016667            0.519792
# 23                          3.615385            0.009615            0.602163
# 24                          3.250000            0.005208            0.903646
# 25                          4.166667            0.057292            0.858724
# 26                          3.666667            0.028646            1.039497
# 27                          3.450000            0.012891            0.898438
# 28                          3.550000            0.056445            0.898633
# 29                          3.650000            0.128125            0.848828
# 30                          3.750000            0.064062            0.673828
# 31                          4.523810            0.030506            0.511347
# 32                          4.409091            0.014560            0.743608
# 33                          4.000000            0.006963            1.050272
# 34                          4.000000            0.049006            0.911754
# 35                          3.952381            0.025670            0.857515
# 36                          3.666667            0.012835            0.999442
# 37                          4.740741            0.042028            0.870443
# 38                          3.782609            0.067935            0.933594
# 39                          4.814815            0.029008            0.694227
# 40                          4.821429            0.049665            0.870292
# 41                          4.000000            0.065204            1.082933
# 42                          3.760000            0.033906            0.961875
# 43                          5.129032            0.013672            0.710938
# 44                          4.709677            0.039094            0.935862
# 45                          5.000000            0.084047            0.790386
# 46                          5.100000            0.043424            0.674805
# 47                          5.172414            0.022461            0.624697
# 48                          5.034483            0.045696            0.725923
# 49                          5.861111            0.073968            0.792474
#
#     Avg. MinMax Vote Diff  Avg. Diff  Avg. Score  Sum of Scores  Avg. Weight  \
# 0                1.000000   0.500000    0.000000       0.000000     1.000000
# 1                0.750000   0.458350    1.000000       2.000000     0.750000
# 2                0.583333   0.319450    1.666667       5.000000     0.583333
# 3                0.375000   0.208338   -0.250000      -0.500000     0.375000
# 4                0.791667   0.458346    0.583333       1.750000     0.458333
# 5                0.796875   0.421880    1.218750       4.875000     0.421875
# 6                0.473958   0.244793    1.406250       8.437500     0.328125
# 7                0.281250   0.144793    0.850000       4.250000     0.193750
# 8                0.528125   0.299486    0.281250       1.406250     0.290625
# 9                0.958333   0.562513    1.145833       6.875000     0.489583
# 10               0.968750   0.526048    1.250000       7.500000     0.406250
# 11               0.750000   0.392860    1.392857       9.750000     0.330357
# 12               0.762500   0.420831    2.187500      21.875000     0.365625
# 13               0.528409   0.342805    1.721591      18.937500     0.257102
# 14               0.408854   0.254344    1.622396      19.468750     0.201172
# 15               0.220881   0.137668    0.012784       0.140625     0.109020
# 16               0.907986   0.488720    0.687500       6.187500     0.286458
# 17               1.187500   0.653411    1.556818      17.125000     0.389205
# 18               1.083333   0.596786    1.716146      20.593750     0.354167
# 19               1.039062   0.602424    2.026042      24.312500     0.342448
# 20               0.786058   0.482171    2.319712      30.156250     0.311298
# 21               0.792411   0.461314    2.504464      35.062500     0.286830
# 22               0.503125   0.293060    1.968750      29.531250     0.200521
# 23               0.592548   0.320115    2.055288      26.718750     0.191106
# 24               0.898438   0.503474    0.588542       7.062500     0.268229
# 25               0.801432   0.483726    0.859375      15.468750     0.256727
# 26               1.010851   0.565393    1.320312      23.765625     0.294705
# 27               0.885547   0.469726    1.694922      33.898438     0.288672
# 28               0.842187   0.484505    1.548047      30.960938     0.244141
# 29               0.720703   0.458662    1.674219      33.484375     0.221875
# 30               0.609766   0.362341    1.937109      38.742188     0.210742
# 31               0.480841   0.299529    1.398624      29.371094     0.147972
# 32               0.729048   0.423032    2.394531      52.679688     0.206854
# 33               1.043308   0.593072    3.492527      80.328125     0.272588
# 34               0.862749   0.506480    3.188210      70.140625     0.233132
# 35               0.831845   0.486976    0.587426      12.335938     0.217076
# 36               0.986607   0.552640    0.961682      20.195312     0.251116
# 37               0.828414   0.461975    1.040148      28.083984     0.208876
# 38               0.865659   0.489698    1.220448      28.070312     0.214674
# 39               0.665220   0.381569    1.112196      30.029297     0.165582
# 40               0.820626   0.487470    1.464914      41.017578     0.186942
# 41               1.017728   0.608028    2.481070      64.507812     0.254207
# 42               0.927969   0.535472    2.809687      70.242188     0.251875
# 43               0.697266   0.377490    1.971837      61.126953     0.166205
# 44               0.896768   0.511184    2.792276      86.560547     0.212072
# 45               0.706338   0.438317    2.363785      73.277344     0.170520
# 46               0.631380   0.370782    2.354492      70.634766     0.154720
# 47               0.602236   0.329606    2.458984      71.310547     0.148943
# 48               0.680226   0.388828    0.739022      21.431641     0.177869
# 49               0.718506   0.425179    0.908610      32.709961     0.182773
#
#     Sum of Weights
# 0         1.000000
# 1         1.500000
# 2         1.750000
# 3         0.750000
# 4         1.375000
# 5         1.687500
# 6         1.968750
# 7         0.968750
# 8         1.453125
# 9         2.937500
# 10        2.437500
# 11        2.312500
# 12        3.656250
# 13        2.828125
# 14        2.414062
# 15        1.199219
# 16        2.578125
# 17        4.281250
# 18        4.250000
# 19        4.109375
# 20        4.046875
# 21        4.015625
# 22        3.007812
# 23        2.484375
# 24        3.218750
# 25        4.621094
# 26        5.304688
# 27        5.773438
# 28        4.882812
# 29        4.437500
# 30        4.214844
# 31        3.107422
# 32        4.550781
# 33        6.269531
# 34        5.128906
# 35        4.558594
# 36        5.273438
# 37        5.639648
# 38        4.937500
# 39        4.470703
# 40        5.234375
# 41        6.609375
# 42        6.296875
# 43        5.152344
# 44        6.574219
# 45        5.286133
# 46        4.641602
# 47        4.319336
# 48        5.158203
# 49        6.579834

# %% [markdown]
# ### 4b. Create additional metrics, *go back and modify strategies_for_n() metrics if applicable*

# %% [markdown]
# #### Test 1: Efficiency (strats/credits) * sum of scores per credit * spread (avg minmax/avg diff)

# %%
res['test1'] = (res.Strategies/res.Credits) * (res['Sum of Scores']/res.Credits) * ((res['Avg. MinMax Vote Diff']/res['Avg. Diff'])/res.Credits)

# %%
res

# %%
res.sort_values(by = 'test1', ascending = False).head(25)

# %%
res['Avg. Min Vote Diff'].describe()

# %%
res['score_per_credit'] = res['Sum of Scores'] / res['Credits']
res

# %%
res.sort_values(by = 'score_per_credit')

# %%
res['score2'] = res.score_per_credit * (res['Strategies'] / res['Credits'])

# %%
res.sort_values(by = 'score2')

# %%
res[res.score_per_credit > 1].score_per_credit.nlargest(10)

# %%
res['Avg. MinMax Vote Diff'].plot()

# %% [markdown]
# ---

# %% [markdown]
# # To Do:
# ### 1. Write the function that loops through all n, and returns the optimal vote credit total for each.
# ### 2. Redo this with negative voting.
# ### 3. Explore continuous voting.

# %% [markdown]
# ##### Discovery: The minimal number of credits which allow for strategies where no two numbers are equal (min diff > 0) is equal to the [n-1, n-2,...,0] strategy credit level.
